# %%
# default_exp val

# %%
# %reload_ext autoreload
# %autoreload 2

# %%
from nbdev.export import create_config

create_config(host='localhost', lib_name='code', user='ian', title='title1', copyright='cp1', description='des1')

# %% [markdown]
# # the official script for evalution, which is posted in the forum.
# https://tianchi.aliyun.com/forum/postDetail?spm=5176.12586969.1002.3.6c3f5619NDeQ04&postId=102089
# # [Must Read!] Official Script for Evaluation

# %%
# export

# coding=utf-8
# from __future__ import division
# from __future__ import print_function

import datetime
import json
import sys
import time
from collections import defaultdict

import numpy as np
import pandas as pd
from loguru import logger
import os

# %% [markdown]
# ## evaluate_each_phase

# %%
# export

# the higher scores, the better performance
def evaluate_each_phase(predictions: dict, answers: dict):
    """
    
    predictions: dict
        key是user_id, value是list [pred_item_id_1,pred_item_id_2...]
    answers: dict
        key是user_id, value是(item_id, item_degree)
    """
    list_item_degress = []
    for user_id in answers:
        item_id, item_degree = answers[user_id]  # item_degree 应该是内置的表示新颖性的指标，越小，越新颖
        list_item_degress.append(item_degree)
    list_item_degress.sort()
    median_item_degree = list_item_degress[len(list_item_degress) // 2]

    num_cases_full = 0.0
    ndcg_50_full = 0.0
    ndcg_50_half = 0.0
    num_cases_half = 0.0
    hitrate_50_full = 0.0
    hitrate_50_half = 0.0
    for user_id in answers:
        item_id, item_degree = answers[user_id]
        rank = 0
        # 把正确的item_id和 预测值 依次 比对，
        while rank < 50 and predictions[user_id][rank] != item_id:
            rank += 1
        num_cases_full += 1.0
        if rank < 50:
            ndcg_50_full += 1.0 / np.log2(rank + 2.0)
            hitrate_50_full += 1.0
        if item_degree <= median_item_degree:
            num_cases_half += 1.0
            if rank < 50:
                ndcg_50_half += 1.0 / np.log2(rank + 2.0)
                hitrate_50_half += 1.0
    ndcg_50_full /= num_cases_full
    hitrate_50_full /= num_cases_full
    ndcg_50_half /= num_cases_half
    hitrate_50_half /= num_cases_half
    return np.array([hitrate_50_full, ndcg_50_full,hitrate_50_half, ndcg_50_half], dtype=np.float32)

# %% [markdown]
# ## evaluate

# %%
# export

# submit_fname is the path to the file submitted by the participants.
# debias_track_answer.csv is the standard answer, which is not released.
def evaluate(submit_fname,
             answer_fname='data_gen/debias_track_answer.csv', current_time=None):
    schedule_in_unix_time = [
        0,  # ........ 1970-01-01 08:00:00 (T=0)
        1586534399,  # 2020-04-10 23:59:59 (T=1)
        1587139199,  # 2020-04-17 23:59:59 (T=2)
        1587743999,  # 2020-04-24 23:59:59 (T=3)
        1588348799,  # 2020-05-01 23:59:59 (T=4)
        1588953599,  # 2020-05-08 23:59:59 (T=5)
        1589558399,  # 2020-05-15 23:59:59 (T=6)
        1590163199,  # 2020-05-22 23:59:59 (T=7)
        1590767999,  # 2020-05-29 23:59:59 (T=8)
        1591372799  # .2020-06-05 23:59:59 (T=9)
    ]
    assert len(schedule_in_unix_time) == 10
    for i in range(1, len(schedule_in_unix_time) - 1):
        # 604800 == one week
        assert schedule_in_unix_time[i] + 604800 == schedule_in_unix_time[i + 1]

    if current_time is None:
        current_time = int(time.time())
    print('current_time:', current_time)
    print('date_time:', datetime.datetime.fromtimestamp(current_time))
    current_phase = 0
    while (current_phase < 9) and (
            current_time > schedule_in_unix_time[current_phase + 1]):
        current_phase += 1
    print('current_phase:', current_phase)
#     current_phase = 4
    try:
        answers = [{} for _ in range(10)]
        with open(answer_fname, 'r') as fin:
            for line in fin:
                line = [int(x) for x in line.split(',')]
                phase_id, user_id, item_id, item_degree = line
                assert user_id % 11 == phase_id
                # exactly one test case for each user_id
                answers[phase_id][user_id] = (item_id, item_degree)
    except Exception as _:
        print('server-side error: answer file incorrect')

    try:
        predictions = {}
        with open(submit_fname, 'r') as fin:
            for line in fin:
                line = line.strip()
                if line == '':
                    continue
                line = line.split(',')
                user_id = int(line[0])
                if user_id in predictions:
                    print('submitted duplicate user_ids')
                item_ids = [int(i) for i in line[1:]]
                if len(item_ids) != 50:
                    print('each row need have 50 items')
                if len(set(item_ids)) != 50:
                    return report_error(
                        stdout, 'each row need have 50 DISTINCT items')
                predictions[user_id] = item_ids
    except Exception as _:
        print('submission not in correct format')

    scores = np.zeros(4, dtype=np.float32)

    # The final winning teams will be decided based on phase T=7,8,9 only.
    # We thus fix the scores to 1.0 for phase 0,1,2,...,6 at the final stage.
    if current_phase >= 7:  # if at the final stage, i.e., T=7,8,9
        scores += 7.0  # then fix the scores to 1.0 for phase 0,1,2,...,6
    phase_beg = (7 if (current_phase >= 7) else 0)
    phase_end = current_phase + 1
    r_dict = {}  # 每阶段成绩
    for phase_id in range(phase_beg, phase_end):
        for user_id in answers[phase_id]:
            if user_id not in predictions:
                print('user_id %d of phase %d not in submission' % (
                        user_id, phase_id))
        try:
            # We sum the scores from all the phases, instead of averaging them.
            rs = evaluate_each_phase(predictions, answers[phase_id])
            print(f'phase_id: {phase_id}, score: {rs}')
            r_dict[phase_id] = rs
            scores += rs
        except Exception as _:
            print('error occurred during evaluation')

#     print(score=float(scores[0]))
#     print(ndcg_50_full=float(scores[0]), ndcg_50_half=float(scores[1]),
#         hitrate_50_full=float(scores[2]), hitrate_50_half=float(scores[3]))
#     print(float(scores[1]))
#     print(float(scores[0]), float(scores[1]), float(scores[2]), float(scores[3]))
    return (float(scores[0]), float(scores[1]), float(scores[2]), float(scores[3])), r_dict

# %% [markdown]
# ## `_create_answer_file_for_evaluation`

# %%
# export

# FYI. You can create a fake answer file for validation based on this. For example,
# you can mask the latest ONE click made by each user in underexpose_test_click-T.csv,
# and use those masked clicks to create your own validation set, i.e.,
# a fake underexpose_test_qtime_with_answer-T.csv for validation.
def _create_answer_file_for_evaluation(answer_fname='data_gen/debias_track_answer.csv'):
    train = './data_origin/underexpose_train/underexpose_train_click-%d.csv'
    test = './data_origin/underexpose_test/underexpose_test_click-%d/underexpose_test_click-%d.csv'

    # underexpose_test_qtime-T.csv contains only <user_id, item_id>
    # underexpose_test_qtime_with_answer-T.csv contains <user_id, item_id, time>
    answer = 'data_gen/underexpose_test_qtime_with_answer-%d.csv'  # not released

    item_deg = defaultdict(lambda: 0)
    now_phase = 5
    with open(answer_fname, 'w') as fout:
        for phase_id in range(now_phase+1):
#             print(phase_id)
            with open(train % phase_id) as fin:
                for line in fin:
                    user_id, item_id, timestamp = line.split(',')
                    user_id, item_id, timestamp = (
                        int(user_id), int(item_id), float(timestamp))
                    item_deg[item_id] += 1
            with open(test % (phase_id, phase_id)) as fin:
                for line in fin:
                    user_id, item_id, timestamp = line.split(',')
                    user_id, item_id, timestamp = (
                        int(user_id), int(item_id), float(timestamp))
                    item_deg[item_id] += 1
            with open(answer % phase_id) as fin:
                for line in fin:
                    user_id, item_id, timestamp = line.split(',')
                    user_id, item_id, timestamp = (
                        int(user_id), int(item_id), float(timestamp))
                    assert user_id % 11 == phase_id
                    print(phase_id, user_id, item_id, item_deg[item_id],
                          sep=',', file=fout)

# %%
# export

def create_underexpose_test_qtime_with_answer(now_phase):
    test_path = './data_origin/underexpose_test'
    for c in range(now_phase + 1):  
        logger.info(f'phase: {c}') 
        ff = f'data_gen/underexpose_test_qtime_with_answer-{c}.csv'
        if os.path.exists(ff): 
            logger.info(f'{ff} exists!')
            continue
        click_test1 = pd.read_csv(test_path + '/underexpose_test_click-{}/underexpose_test_click-{}.csv'.format(c, c), header=None,  names=['user_id', 'item_id', 'time']) 
        click_test1.sort_values(['user_id', 'time']).drop_duplicates(subset=['user_id','item_id'],keep='last').reset_index(drop=True).to_csv(ff, index=None, header=None)

# %% [markdown]
# # main

# %%
# export

def main(now_phase, submit_fname): 
    create_underexpose_test_qtime_with_answer(now_phase)
    _create_answer_file_for_evaluation()
    r = evaluate(submit_fname)
    return r

# %%
now_phase = 5
submit_fname = '/Users/luoyonggui/Downloads/baseline1_itemcf1414.csv'
main(now_phase, submit_fname)
# Out:
# 2020-05-11 15:42:29.240 | INFO     | __main__:create_underexpose_test_qtime_with_answer:6 - phase: 0
# 2020-05-11 15:42:29.505 | INFO     | __main__:create_underexpose_test_qtime_with_answer:6 - phase: 1
# 2020-05-11 15:42:29.596 | INFO     | __main__:create_underexpose_test_qtime_with_answer:6 - phase: 2
# 2020-05-11 15:42:29.681 | INFO     | __main__:create_underexpose_test_qtime_with_answer:6 - phase: 3
# 2020-05-11 15:42:29.770 | INFO     | __main__:create_underexpose_test_qtime_with_answer:6 - phase: 4
# 2020-05-11 15:42:29.869 | INFO     | __main__:create_underexpose_test_qtime_with_answer:6 - phase: 5
# 0
# 1
# 2
# 3
# 4
# 5
# current_time: 1589182952
# date_time: 2020-05-11 15:42:32
# current_phase: 5
# phase_id: 0, score: [0.7678894  0.25456    0.82934785 0.30067682]
# phase_id: 1, score: [0.77925843 0.25543353 0.86615044 0.31160575]
# phase_id: 2, score: [0.791716   0.25759798 0.84988177 0.30619693]
# phase_id: 3, score: [0.7671642  0.24578968 0.83682984 0.29307976]
# phase_id: 4, score: [0.67564404 0.21810669 0.75482404 0.26287678]
# user_id 16 of phase 5 not in submission
# user_id 27 of phase 5 not in submission
# user_id 49 of phase 5 not in submission
# user_id 71 of phase 5 not in submission
# user_id 82 of phase 5 not in submission
# user_id 93 of phase 5 not in submission
# user_id 115 of phase 5 not in submission
# user_id 126 of phase 5 not in submission
# user_id 137 of phase 5 not in submission
# user_id 148 of phase 5 not in submission
# user_id 159 of phase 5 not in submission
# user_id 170 of phase 5 not in submission
# user_id 192 of phase 5 not in submission
# user_id 203 of phase 5 not in submission
# user_id 225 of phase 5 not in submission
# user_id 258 of phase 5 not in submission
# user_id 291 of phase 5 not in submission
# user_id 313 of phase 5 not in submission
# user_id 335 of phase 5 not in submission
# user_id 346 of phase 5 not in submission
# user_id 379 of phase 5 not in submission
# user_id 401 of phase 5 not in submission
# user_id 423 of phase 5 not in submission
# user_id 434 of phase 5 not in submission
# user_id 456 of phase 5 not in submission
# user_id 500 of phase 5 not in submission
# user_id 522 of phase 5 not in submission
# user_id 555 of phase 5 not in submission
# user_id 588 of phase 5 not in submission
# user_id 599 of phase 5 not in submission
# user_id 632 of phase 5 not in submission
# user_id 643 of phase 5 not in submission
# user_id 654 of phase 5 not in submission
# user_id 665 of phase 5 not in submission
# user_id 676 of phase 5 not in submission
# user_id 698 of phase 5 not in submission
# user_id 720 of phase 5 not in submission
# user_id 731 of phase 5 not in submission
# user_id 742 of phase 5 not in submission
# user_id 753 of phase 5 not in submission
# user_id 764 of phase 5 not in submission
# user_id 775 of phase 5 not in submission
# user_id 797 of phase 5 not in submission
# user_id 808 of phase 5 not in submission
# user_id 819 of phase 5 not in submission
# user_id 830 of phase 5 not in submission
# user_id 841 of phase 5 not in submission
# user_id 863 of phase 5 not in submission
# user_id 885 of phase 5 not in submission
# user_id 918 of phase 5 not in submission
# user_id 929 of phase 5 not in submission
# user_id 940 of phase 5 not in submission
# user_id 951 of phase 5 not in submission
# user_id 962 of phase 5 not in submission
# user_id 973 of phase 5 not in submission
# user_id 984 of phase 5 not in submission
# user_id 995 of phase 5 not in submission
# user_id 1006 of phase 5 not in submission
# user_id 1017 of phase 5 not in submission
# user_id 1028 of phase 5 not in submission
# user_id 1050 of phase 5 not in submission
# user_id 1094 of phase 5 not in submission
# user_id 1105 of phase 5 not in submission
# user_id 1116 of phase 5 not in submission
# user_id 1127 of phase 5 not in submission
# user_id 1138 of phase 5 not in submission
# user_id 1149 of phase 5 not in submission
# user_id 1171 of phase 5 not in submission
# user_id 1193 of phase 5 not in submission
# user_id 1204 of phase 5 not in submission
# user_id 1215 of phase 5 not in submission
# user_id 1226 of phase 5 not in submission
# user_id 1237 of phase 5 not in submission
# user_id 1248 of phase 5 not in submission
# user_id 1281 of phase 5 not in submission
# user_id 1292 of phase 5 not in submission
# user_id 1303 of phase 5 not in submission
# user_id 1314 of phase 5 not in submission
# user_id 1336 of phase 5 not in submission
# user_id 1347 of phase 5 not in submission
# user_id 1380 of phase 5 not in submission
# user_id 1391 of phase 5 not in submission
# user_id 1402 of phase 5 not in submission
# user_id 1413 of phase 5 not in submission
# user_id 1457 of phase 5 not in submission
# user_id 1479 of phase 5 not in submission
# user_id 1501 of phase 5 not in submission
# user_id 1512 of phase 5 not in submission
# user_id 1523 of phase 5 not in submission
# user_id 1545 of phase 5 not in submission
# user_id 1556 of phase 5 not in submission
# user_id 1567 of phase 5 not in submission
# user_id 1589 of phase 5 not in submission
# user_id 1600 of phase 5 not in submission
# user_id 1611 of phase 5 not in submission
# user_id 1622 of phase 5 not in submission
# user_id 1644 of phase 5 not in submission
# user_id 1655 of phase 5 not in submission
# user_id 1666 of phase 5 not in submission
# user_id 1677 of phase 5 not in submission
# user_id 1688 of phase 5 not in submission
# user_id 1699 of phase 5 not in submission
# user_id 1710 of phase 5 not in submission
# user_id 1754 of phase 5 not in submission
# user_id 1765 of phase 5 not in submission
# user_id 1776 of phase 5 not in submission
# user_id 1798 of phase 5 not in submission
# user_id 1809 of phase 5 not in submission
# user_id 1820 of phase 5 not in submission
# user_id 1831 of phase 5 not in submission
# user_id 1842 of phase 5 not in submission
# user_id 1853 of phase 5 not in submission
# user_id 1875 of phase 5 not in submission
# user_id 1886 of phase 5 not in submission
# user_id 1897 of phase 5 not in submission
# user_id 1919 of phase 5 not in submission
# user_id 1930 of phase 5 not in submission
# user_id 1952 of phase 5 not in submission
# user_id 1974 of phase 5 not in submission
# user_id 1985 of phase 5 not in submission
# user_id 1996 of phase 5 not in submission
# user_id 2007 of phase 5 not in submission
# user_id 2029 of phase 5 not in submission
# user_id 2040 of phase 5 not in submission
# user_id 2051 of phase 5 not in submission
# user_id 2062 of phase 5 not in submission
# user_id 2073 of phase 5 not in submission
# user_id 2084 of phase 5 not in submission
# user_id 2095 of phase 5 not in submission
# user_id 2106 of phase 5 not in submission
# user_id 2117 of phase 5 not in submission
# user_id 2139 of phase 5 not in submission
# user_id 2150 of phase 5 not in submission
# user_id 2172 of phase 5 not in submission
# user_id 2183 of phase 5 not in submission
# user_id 2194 of phase 5 not in submission
# user_id 2205 of phase 5 not in submission
# user_id 2249 of phase 5 not in submission
# user_id 2260 of phase 5 not in submission
# user_id 2271 of phase 5 not in submission
# user_id 2304 of phase 5 not in submission
# user_id 2315 of phase 5 not in submission
# user_id 2326 of phase 5 not in submission
# user_id 2337 of phase 5 not in submission
# user_id 2348 of phase 5 not in submission
# user_id 2370 of phase 5 not in submission
# user_id 2392 of phase 5 not in submission
# user_id 2425 of phase 5 not in submission
# user_id 2436 of phase 5 not in submission
# user_id 2447 of phase 5 not in submission
# user_id 2480 of phase 5 not in submission
# user_id 2491 of phase 5 not in submission
# user_id 2502 of phase 5 not in submission
# user_id 2535 of phase 5 not in submission
# user_id 2557 of phase 5 not in submission
# user_id 2568 of phase 5 not in submission
# user_id 2601 of phase 5 not in submission
# user_id 2623 of phase 5 not in submission
# user_id 2634 of phase 5 not in submission
# user_id 2645 of phase 5 not in submission
# user_id 2656 of phase 5 not in submission
# user_id 2667 of phase 5 not in submission
# user_id 2678 of phase 5 not in submission
# user_id 2700 of phase 5 not in submission
# user_id 2711 of phase 5 not in submission
# user_id 2722 of phase 5 not in submission
# user_id 2733 of phase 5 not in submission
# user_id 2744 of phase 5 not in submission
# user_id 2766 of phase 5 not in submission
# user_id 2777 of phase 5 not in submission
# user_id 2788 of phase 5 not in submission
# user_id 2799 of phase 5 not in submission
# user_id 2821 of phase 5 not in submission
# user_id 2832 of phase 5 not in submission
# user_id 2854 of phase 5 not in submission
# user_id 2865 of phase 5 not in submission
# user_id 2876 of phase 5 not in submission
# user_id 2898 of phase 5 not in submission
# user_id 2920 of phase 5 not in submission
# user_id 2964 of phase 5 not in submission
# user_id 2975 of phase 5 not in submission
# user_id 2986 of phase 5 not in submission
# user_id 2997 of phase 5 not in submission
# user_id 3008 of phase 5 not in submission
# user_id 3019 of phase 5 not in submission
# user_id 3063 of phase 5 not in submission
# user_id 3085 of phase 5 not in submission
# user_id 3118 of phase 5 not in submission
# user_id 3140 of phase 5 not in submission
# user_id 3184 of phase 5 not in submission
# user_id 3217 of phase 5 not in submission
# user_id 3228 of phase 5 not in submission
# user_id 3239 of phase 5 not in submission
# user_id 3250 of phase 5 not in submission
# user_id 3272 of phase 5 not in submission
# user_id 3294 of phase 5 not in submission
# user_id 3305 of phase 5 not in submission
# user_id 3316 of phase 5 not in submission
# user_id 3327 of phase 5 not in submission
# user_id 3338 of phase 5 not in submission
# user_id 3371 of phase 5 not in submission
# user_id 3393 of phase 5 not in submission
# user_id 3415 of phase 5 not in submission
# user_id 3448 of phase 5 not in submission
# user_id 3459 of phase 5 not in submission
# user_id 3470 of phase 5 not in submission
# user_id 3492 of phase 5 not in submission
# user_id 3525 of phase 5 not in submission
# user_id 3536 of phase 5 not in submission
# user_id 3558 of phase 5 not in submission
# user_id 3580 of phase 5 not in submission
# user_id 3602 of phase 5 not in submission
# user_id 3624 of phase 5 not in submission
# user_id 3635 of phase 5 not in submission
# user_id 3646 of phase 5 not in submission
# user_id 3657 of phase 5 not in submission
# user_id 3668 of phase 5 not in submission
# user_id 3701 of phase 5 not in submission
# user_id 3723 of phase 5 not in submission
# user_id 3745 of phase 5 not in submission
# user_id 3756 of phase 5 not in submission
# user_id 3778 of phase 5 not in submission
# user_id 3800 of phase 5 not in submission
# user_id 3822 of phase 5 not in submission
# user_id 3866 of phase 5 not in submission
# user_id 3888 of phase 5 not in submission
# user_id 3921 of phase 5 not in submission
# user_id 3932 of phase 5 not in submission
# user_id 3943 of phase 5 not in submission
# user_id 3965 of phase 5 not in submission
# user_id 3987 of phase 5 not in submission
# user_id 3998 of phase 5 not in submission
# user_id 4009 of phase 5 not in submission
# user_id 4020 of phase 5 not in submission
# user_id 4031 of phase 5 not in submission
# user_id 4053 of phase 5 not in submission
# user_id 4075 of phase 5 not in submission
# user_id 4086 of phase 5 not in submission
# user_id 4108 of phase 5 not in submission
# user_id 4119 of phase 5 not in submission
# user_id 4141 of phase 5 not in submission
# user_id 4152 of phase 5 not in submission
# user_id 4163 of phase 5 not in submission
# user_id 4174 of phase 5 not in submission
# user_id 4185 of phase 5 not in submission
# user_id 4218 of phase 5 not in submission
# user_id 4240 of phase 5 not in submission
# user_id 4251 of phase 5 not in submission
# user_id 4262 of phase 5 not in submission
# user_id 4273 of phase 5 not in submission
# user_id 4306 of phase 5 not in submission
# user_id 4328 of phase 5 not in submission
# user_id 4339 of phase 5 not in submission
# user_id 4350 of phase 5 not in submission
# user_id 4394 of phase 5 not in submission
# user_id 4405 of phase 5 not in submission
# user_id 4416 of phase 5 not in submission
# user_id 4427 of phase 5 not in submission
# user_id 4471 of phase 5 not in submission
# user_id 4482 of phase 5 not in submission
# user_id 4493 of phase 5 not in submission
# user_id 4515 of phase 5 not in submission
# user_id 4548 of phase 5 not in submission
# user_id 4570 of phase 5 not in submission
# user_id 4581 of phase 5 not in submission
# user_id 4603 of phase 5 not in submission
# user_id 4614 of phase 5 not in submission
# user_id 4625 of phase 5 not in submission
# user_id 4636 of phase 5 not in submission
# user_id 4669 of phase 5 not in submission
# user_id 4691 of phase 5 not in submission
# user_id 4702 of phase 5 not in submission
# user_id 4735 of phase 5 not in submission
# user_id 4757 of phase 5 not in submission
# user_id 4768 of phase 5 not in submission
# user_id 4779 of phase 5 not in submission
# user_id 4790 of phase 5 not in submission
# user_id 4812 of phase 5 not in submission
# user_id 4823 of phase 5 not in submission
# user_id 4834 of phase 5 not in submission
# user_id 4845 of phase 5 not in submission
# user_id 4856 of phase 5 not in submission
# user_id 4867 of phase 5 not in submission
# user_id 4878 of phase 5 not in submission
# user_id 4889 of phase 5 not in submission
# user_id 4911 of phase 5 not in submission
# user_id 4955 of phase 5 not in submission
# user_id 4966 of phase 5 not in submission
# user_id 4977 of phase 5 not in submission
# user_id 4988 of phase 5 not in submission
# user_id 4999 of phase 5 not in submission
# user_id 5010 of phase 5 not in submission
# user_id 5087 of phase 5 not in submission
# user_id 5109 of phase 5 not in submission
# user_id 5120 of phase 5 not in submission
# user_id 5131 of phase 5 not in submission
# user_id 5142 of phase 5 not in submission
# user_id 5164 of phase 5 not in submission
# user_id 5186 of phase 5 not in submission
# user_id 5197 of phase 5 not in submission
# user_id 5219 of phase 5 not in submission
# user_id 5263 of phase 5 not in submission
# user_id 5285 of phase 5 not in submission
# user_id 5318 of phase 5 not in submission
# user_id 5340 of phase 5 not in submission
# user_id 5362 of phase 5 not in submission
# user_id 5373 of phase 5 not in submission
# user_id 5384 of phase 5 not in submission
# user_id 5395 of phase 5 not in submission
# user_id 5417 of phase 5 not in submission
# user_id 5439 of phase 5 not in submission
# user_id 5450 of phase 5 not in submission
# user_id 5461 of phase 5 not in submission
# user_id 5472 of phase 5 not in submission
# user_id 5494 of phase 5 not in submission
# user_id 5527 of phase 5 not in submission
# user_id 5560 of phase 5 not in submission
# user_id 5571 of phase 5 not in submission
# user_id 5582 of phase 5 not in submission
# user_id 5615 of phase 5 not in submission
# user_id 5626 of phase 5 not in submission
# user_id 5648 of phase 5 not in submission
# user_id 5659 of phase 5 not in submission
# user_id 5681 of phase 5 not in submission
# user_id 5703 of phase 5 not in submission
# user_id 5714 of phase 5 not in submission
# user_id 5725 of phase 5 not in submission
# user_id 5736 of phase 5 not in submission
# user_id 5758 of phase 5 not in submission
# user_id 5769 of phase 5 not in submission
# user_id 5780 of phase 5 not in submission
# user_id 5791 of phase 5 not in submission
# user_id 5835 of phase 5 not in submission
# user_id 5857 of phase 5 not in submission
# user_id 5890 of phase 5 not in submission
# user_id 5912 of phase 5 not in submission
# user_id 5923 of phase 5 not in submission
# user_id 5934 of phase 5 not in submission
# user_id 5967 of phase 5 not in submission
# user_id 5989 of phase 5 not in submission
# user_id 6011 of phase 5 not in submission
# user_id 6022 of phase 5 not in submission
# user_id 6055 of phase 5 not in submission
# user_id 6066 of phase 5 not in submission
# user_id 6077 of phase 5 not in submission
# user_id 6088 of phase 5 not in submission
# user_id 6110 of phase 5 not in submission
# user_id 6121 of phase 5 not in submission
# user_id 6132 of phase 5 not in submission
# user_id 6165 of phase 5 not in submission
# user_id 6176 of phase 5 not in submission
# user_id 6220 of phase 5 not in submission
# user_id 6253 of phase 5 not in submission
# user_id 6275 of phase 5 not in submission
# user_id 6286 of phase 5 not in submission
# user_id 6297 of phase 5 not in submission
# user_id 6308 of phase 5 not in submission
# user_id 6330 of phase 5 not in submission
# user_id 6341 of phase 5 not in submission
# user_id 6352 of phase 5 not in submission
# user_id 6363 of phase 5 not in submission
# user_id 6374 of phase 5 not in submission
# user_id 6396 of phase 5 not in submission
# user_id 6407 of phase 5 not in submission
# user_id 6429 of phase 5 not in submission
# user_id 6451 of phase 5 not in submission
# user_id 6462 of phase 5 not in submission
# user_id 6473 of phase 5 not in submission
# user_id 6484 of phase 5 not in submission
# user_id 6495 of phase 5 not in submission
# user_id 6506 of phase 5 not in submission
# user_id 6539 of phase 5 not in submission
# user_id 6561 of phase 5 not in submission
# user_id 6572 of phase 5 not in submission
# user_id 6583 of phase 5 not in submission
# user_id 6616 of phase 5 not in submission
# user_id 6627 of phase 5 not in submission
# user_id 6638 of phase 5 not in submission
# user_id 6660 of phase 5 not in submission
# user_id 6671 of phase 5 not in submission
# user_id 6682 of phase 5 not in submission
# user_id 6715 of phase 5 not in submission
# user_id 6726 of phase 5 not in submission
# user_id 6748 of phase 5 not in submission
# user_id 6759 of phase 5 not in submission
# user_id 6770 of phase 5 not in submission
# user_id 6792 of phase 5 not in submission
# user_id 6825 of phase 5 not in submission
# user_id 6847 of phase 5 not in submission
# user_id 6858 of phase 5 not in submission
# user_id 6880 of phase 5 not in submission
# user_id 6924 of phase 5 not in submission
# user_id 6935 of phase 5 not in submission
# user_id 6946 of phase 5 not in submission
# user_id 6957 of phase 5 not in submission
# user_id 6968 of phase 5 not in submission
# user_id 6979 of phase 5 not in submission
# user_id 6990 of phase 5 not in submission
# user_id 7001 of phase 5 not in submission
# user_id 7012 of phase 5 not in submission
# user_id 7023 of phase 5 not in submission
# user_id 7056 of phase 5 not in submission
# user_id 7067 of phase 5 not in submission
# user_id 7089 of phase 5 not in submission
# user_id 7111 of phase 5 not in submission
# user_id 7122 of phase 5 not in submission
# user_id 7133 of phase 5 not in submission
# user_id 7155 of phase 5 not in submission
# user_id 7166 of phase 5 not in submission
# user_id 7177 of phase 5 not in submission
# user_id 7199 of phase 5 not in submission
# user_id 7210 of phase 5 not in submission
# user_id 7221 of phase 5 not in submission
# user_id 7276 of phase 5 not in submission
# user_id 7287 of phase 5 not in submission
# user_id 7309 of phase 5 not in submission
# user_id 7320 of phase 5 not in submission
# user_id 7331 of phase 5 not in submission
# user_id 7353 of phase 5 not in submission
# user_id 7364 of phase 5 not in submission
# user_id 7375 of phase 5 not in submission
# user_id 7397 of phase 5 not in submission
# user_id 7408 of phase 5 not in submission
# user_id 7419 of phase 5 not in submission
# user_id 7441 of phase 5 not in submission
# user_id 7452 of phase 5 not in submission
# user_id 7463 of phase 5 not in submission
# user_id 7485 of phase 5 not in submission
# user_id 7496 of phase 5 not in submission
# user_id 7507 of phase 5 not in submission
# user_id 7518 of phase 5 not in submission
# user_id 7529 of phase 5 not in submission
# user_id 7540 of phase 5 not in submission
# user_id 7562 of phase 5 not in submission
# user_id 7584 of phase 5 not in submission
# user_id 7595 of phase 5 not in submission
# user_id 7606 of phase 5 not in submission
# user_id 7639 of phase 5 not in submission
# user_id 7650 of phase 5 not in submission
# user_id 7661 of phase 5 not in submission
# user_id 7672 of phase 5 not in submission
# user_id 7683 of phase 5 not in submission
# user_id 7705 of phase 5 not in submission
# user_id 7716 of phase 5 not in submission
# user_id 7727 of phase 5 not in submission
# user_id 7738 of phase 5 not in submission
# user_id 7749 of phase 5 not in submission
# user_id 7771 of phase 5 not in submission
# user_id 7782 of phase 5 not in submission
# user_id 7804 of phase 5 not in submission
# user_id 7815 of phase 5 not in submission
# user_id 7826 of phase 5 not in submission
# user_id 7837 of phase 5 not in submission
# user_id 7859 of phase 5 not in submission
# user_id 7881 of phase 5 not in submission
# user_id 7892 of phase 5 not in submission
# user_id 7925 of phase 5 not in submission
# user_id 7936 of phase 5 not in submission
# user_id 7958 of phase 5 not in submission
# user_id 7980 of phase 5 not in submission
# user_id 8002 of phase 5 not in submission
# user_id 8013 of phase 5 not in submission
# user_id 8035 of phase 5 not in submission
# user_id 8046 of phase 5 not in submission
# user_id 8090 of phase 5 not in submission
# user_id 8101 of phase 5 not in submission
# user_id 8112 of phase 5 not in submission
# user_id 8123 of phase 5 not in submission
# user_id 8134 of phase 5 not in submission
# user_id 8145 of phase 5 not in submission
# user_id 8156 of phase 5 not in submission
# user_id 8167 of phase 5 not in submission
# user_id 8178 of phase 5 not in submission
# user_id 8200 of phase 5 not in submission
# user_id 8222 of phase 5 not in submission
# user_id 8266 of phase 5 not in submission
# user_id 8277 of phase 5 not in submission
# user_id 8310 of phase 5 not in submission
# user_id 8321 of phase 5 not in submission
# user_id 8332 of phase 5 not in submission
# user_id 8343 of phase 5 not in submission
# user_id 8354 of phase 5 not in submission
# user_id 8376 of phase 5 not in submission
# user_id 8387 of phase 5 not in submission
# user_id 8398 of phase 5 not in submission
# user_id 8409 of phase 5 not in submission
# user_id 8431 of phase 5 not in submission
# user_id 8453 of phase 5 not in submission
# user_id 8464 of phase 5 not in submission
# user_id 8475 of phase 5 not in submission
# user_id 8486 of phase 5 not in submission
# user_id 8508 of phase 5 not in submission
# user_id 8530 of phase 5 not in submission
# user_id 8541 of phase 5 not in submission
# user_id 8574 of phase 5 not in submission
# user_id 8607 of phase 5 not in submission
# user_id 8651 of phase 5 not in submission
# user_id 8662 of phase 5 not in submission
# user_id 8673 of phase 5 not in submission
# user_id 8684 of phase 5 not in submission
# user_id 8706 of phase 5 not in submission
# user_id 8717 of phase 5 not in submission
# user_id 8728 of phase 5 not in submission
# user_id 8750 of phase 5 not in submission
# user_id 8761 of phase 5 not in submission
# user_id 8772 of phase 5 not in submission
# user_id 8805 of phase 5 not in submission
# user_id 8816 of phase 5 not in submission
# user_id 8827 of phase 5 not in submission
# user_id 8893 of phase 5 not in submission
# user_id 8904 of phase 5 not in submission
# user_id 8915 of phase 5 not in submission
# user_id 8926 of phase 5 not in submission
# user_id 8937 of phase 5 not in submission
# user_id 8959 of phase 5 not in submission
# user_id 8970 of phase 5 not in submission
# user_id 8981 of phase 5 not in submission
# user_id 8992 of phase 5 not in submission
# user_id 9014 of phase 5 not in submission
# user_id 9025 of phase 5 not in submission
# user_id 9047 of phase 5 not in submission
# user_id 9058 of phase 5 not in submission
# user_id 9069 of phase 5 not in submission
# user_id 9080 of phase 5 not in submission
# user_id 9102 of phase 5 not in submission
# user_id 9124 of phase 5 not in submission
# user_id 9157 of phase 5 not in submission
# user_id 9190 of phase 5 not in submission
# user_id 9212 of phase 5 not in submission
# user_id 9223 of phase 5 not in submission
# user_id 9234 of phase 5 not in submission
# user_id 9245 of phase 5 not in submission
# user_id 9278 of phase 5 not in submission
# user_id 9289 of phase 5 not in submission
# user_id 9300 of phase 5 not in submission
# user_id 9333 of phase 5 not in submission
# user_id 9344 of phase 5 not in submission
# user_id 9355 of phase 5 not in submission
# user_id 9366 of phase 5 not in submission
# user_id 9377 of phase 5 not in submission
# user_id 9399 of phase 5 not in submission
# user_id 9443 of phase 5 not in submission
# user_id 9465 of phase 5 not in submission
# user_id 9476 of phase 5 not in submission
# user_id 9531 of phase 5 not in submission
# user_id 9553 of phase 5 not in submission
# user_id 9564 of phase 5 not in submission
# user_id 9575 of phase 5 not in submission
# user_id 9586 of phase 5 not in submission
# user_id 9597 of phase 5 not in submission
# user_id 9619 of phase 5 not in submission
# user_id 9641 of phase 5 not in submission
# user_id 9674 of phase 5 not in submission
# user_id 9696 of phase 5 not in submission
# user_id 9707 of phase 5 not in submission
# user_id 9718 of phase 5 not in submission
# user_id 9751 of phase 5 not in submission
# user_id 9773 of phase 5 not in submission
# user_id 9784 of phase 5 not in submission
# user_id 9806 of phase 5 not in submission
# user_id 9817 of phase 5 not in submission
# user_id 9828 of phase 5 not in submission
# user_id 9850 of phase 5 not in submission
# user_id 9894 of phase 5 not in submission
# user_id 9905 of phase 5 not in submission
# user_id 9938 of phase 5 not in submission
# user_id 9949 of phase 5 not in submission
# user_id 9960 of phase 5 not in submission
# user_id 9971 of phase 5 not in submission
# user_id 9982 of phase 5 not in submission
# user_id 9993 of phase 5 not in submission
# user_id 10004 of phase 5 not in submission
# user_id 10015 of phase 5 not in submission
# user_id 10037 of phase 5 not in submission
# user_id 10070 of phase 5 not in submission
# user_id 10081 of phase 5 not in submission
# user_id 10092 of phase 5 not in submission
# user_id 10125 of phase 5 not in submission
# user_id 10158 of phase 5 not in submission
# user_id 10191 of phase 5 not in submission
# user_id 10213 of phase 5 not in submission
# user_id 10224 of phase 5 not in submission
# user_id 10246 of phase 5 not in submission
# user_id 10257 of phase 5 not in submission
# user_id 10268 of phase 5 not in submission
# user_id 10290 of phase 5 not in submission
# user_id 10323 of phase 5 not in submission
# user_id 10334 of phase 5 not in submission
# user_id 10345 of phase 5 not in submission
# user_id 10389 of phase 5 not in submission
# user_id 10400 of phase 5 not in submission
# user_id 10411 of phase 5 not in submission
# user_id 10444 of phase 5 not in submission
# user_id 10466 of phase 5 not in submission
# user_id 10477 of phase 5 not in submission
# user_id 10499 of phase 5 not in submission
# user_id 10510 of phase 5 not in submission
# user_id 10521 of phase 5 not in submission
# user_id 10543 of phase 5 not in submission
# user_id 10576 of phase 5 not in submission
# user_id 10587 of phase 5 not in submission
# user_id 10598 of phase 5 not in submission
# user_id 10620 of phase 5 not in submission
# user_id 10631 of phase 5 not in submission
# user_id 10697 of phase 5 not in submission
# user_id 10719 of phase 5 not in submission
# user_id 10730 of phase 5 not in submission
# user_id 10741 of phase 5 not in submission
# user_id 10752 of phase 5 not in submission
# user_id 10763 of phase 5 not in submission
# user_id 10807 of phase 5 not in submission
# user_id 10851 of phase 5 not in submission
# user_id 10862 of phase 5 not in submission
# user_id 10873 of phase 5 not in submission
# user_id 10917 of phase 5 not in submission
# user_id 10928 of phase 5 not in submission
# user_id 10939 of phase 5 not in submission
# user_id 10961 of phase 5 not in submission
# user_id 10972 of phase 5 not in submission
# user_id 10983 of phase 5 not in submission
# user_id 10994 of phase 5 not in submission
# user_id 11016 of phase 5 not in submission
# user_id 11060 of phase 5 not in submission
# user_id 11071 of phase 5 not in submission
# user_id 11082 of phase 5 not in submission
# user_id 11115 of phase 5 not in submission
# user_id 11137 of phase 5 not in submission
# user_id 11170 of phase 5 not in submission
# user_id 11192 of phase 5 not in submission
# user_id 11225 of phase 5 not in submission
# user_id 11236 of phase 5 not in submission
# user_id 11247 of phase 5 not in submission
# user_id 11280 of phase 5 not in submission
# user_id 11302 of phase 5 not in submission
# user_id 11379 of phase 5 not in submission
# user_id 11412 of phase 5 not in submission
# user_id 11445 of phase 5 not in submission
# user_id 11478 of phase 5 not in submission
# user_id 11489 of phase 5 not in submission
# user_id 11500 of phase 5 not in submission
# user_id 11544 of phase 5 not in submission
# user_id 11577 of phase 5 not in submission
# user_id 11599 of phase 5 not in submission
# user_id 11610 of phase 5 not in submission
# user_id 11621 of phase 5 not in submission
# user_id 11643 of phase 5 not in submission
# user_id 11654 of phase 5 not in submission
# user_id 11665 of phase 5 not in submission
# user_id 11676 of phase 5 not in submission
# user_id 11687 of phase 5 not in submission
# user_id 11698 of phase 5 not in submission
# user_id 11709 of phase 5 not in submission
# user_id 11731 of phase 5 not in submission
# user_id 11786 of phase 5 not in submission
# user_id 11797 of phase 5 not in submission
# user_id 11830 of phase 5 not in submission
# user_id 11841 of phase 5 not in submission
# user_id 11852 of phase 5 not in submission
# user_id 11863 of phase 5 not in submission
# user_id 11907 of phase 5 not in submission
# user_id 11929 of phase 5 not in submission
# user_id 11940 of phase 5 not in submission
# user_id 11951 of phase 5 not in submission
# user_id 11962 of phase 5 not in submission
# user_id 11973 of phase 5 not in submission
# user_id 11984 of phase 5 not in submission
# user_id 11995 of phase 5 not in submission
# user_id 12006 of phase 5 not in submission
# user_id 12028 of phase 5 not in submission
# user_id 12039 of phase 5 not in submission
# user_id 12050 of phase 5 not in submission
# user_id 12072 of phase 5 not in submission
# user_id 12105 of phase 5 not in submission
# user_id 12116 of phase 5 not in submission
# user_id 12127 of phase 5 not in submission
# user_id 12138 of phase 5 not in submission
# user_id 12149 of phase 5 not in submission
# user_id 12160 of phase 5 not in submission
# user_id 12204 of phase 5 not in submission
# user_id 12226 of phase 5 not in submission
# user_id 12248 of phase 5 not in submission
# user_id 12281 of phase 5 not in submission
# user_id 12325 of phase 5 not in submission
# user_id 12336 of phase 5 not in submission
# user_id 12347 of phase 5 not in submission
# user_id 12369 of phase 5 not in submission
# user_id 12413 of phase 5 not in submission
# user_id 12424 of phase 5 not in submission
# user_id 12435 of phase 5 not in submission
# user_id 12446 of phase 5 not in submission
# user_id 12457 of phase 5 not in submission
# user_id 12479 of phase 5 not in submission
# user_id 12523 of phase 5 not in submission
# user_id 12534 of phase 5 not in submission
# user_id 12556 of phase 5 not in submission
# user_id 12578 of phase 5 not in submission
# user_id 12589 of phase 5 not in submission
# user_id 12644 of phase 5 not in submission
# user_id 12655 of phase 5 not in submission
# user_id 12666 of phase 5 not in submission
# user_id 12677 of phase 5 not in submission
# user_id 12688 of phase 5 not in submission
# user_id 12699 of phase 5 not in submission
# user_id 12710 of phase 5 not in submission
# user_id 12732 of phase 5 not in submission
# user_id 12743 of phase 5 not in submission
# user_id 12754 of phase 5 not in submission
# user_id 12765 of phase 5 not in submission
# user_id 12787 of phase 5 not in submission
# user_id 12798 of phase 5 not in submission
# user_id 12809 of phase 5 not in submission
# user_id 12820 of phase 5 not in submission
# user_id 12864 of phase 5 not in submission
# user_id 12897 of phase 5 not in submission
# user_id 12908 of phase 5 not in submission
# user_id 12941 of phase 5 not in submission
# user_id 12952 of phase 5 not in submission
# user_id 12974 of phase 5 not in submission
# user_id 13007 of phase 5 not in submission
# user_id 13029 of phase 5 not in submission
# user_id 13040 of phase 5 not in submission
# user_id 13051 of phase 5 not in submission
# user_id 13095 of phase 5 not in submission
# user_id 13117 of phase 5 not in submission
# user_id 13128 of phase 5 not in submission
# user_id 13139 of phase 5 not in submission
# user_id 13161 of phase 5 not in submission
# user_id 13205 of phase 5 not in submission
# user_id 13216 of phase 5 not in submission
# user_id 13227 of phase 5 not in submission
# user_id 13249 of phase 5 not in submission
# user_id 13260 of phase 5 not in submission
# user_id 13304 of phase 5 not in submission
# user_id 13326 of phase 5 not in submission
# user_id 13337 of phase 5 not in submission
# user_id 13359 of phase 5 not in submission
# user_id 13392 of phase 5 not in submission
# user_id 13403 of phase 5 not in submission
# user_id 13414 of phase 5 not in submission
# user_id 13425 of phase 5 not in submission
# user_id 13436 of phase 5 not in submission
# user_id 13447 of phase 5 not in submission
# user_id 13458 of phase 5 not in submission
# user_id 13469 of phase 5 not in submission
# user_id 13480 of phase 5 not in submission
# user_id 13502 of phase 5 not in submission
# user_id 13513 of phase 5 not in submission
# user_id 13590 of phase 5 not in submission
# user_id 13601 of phase 5 not in submission
# user_id 13612 of phase 5 not in submission
# user_id 13634 of phase 5 not in submission
# user_id 13645 of phase 5 not in submission
# user_id 13656 of phase 5 not in submission
# user_id 13700 of phase 5 not in submission
# user_id 13711 of phase 5 not in submission
# user_id 13722 of phase 5 not in submission
# user_id 13777 of phase 5 not in submission
# user_id 13810 of phase 5 not in submission
# user_id 13821 of phase 5 not in submission
# user_id 13854 of phase 5 not in submission
# user_id 13887 of phase 5 not in submission
# user_id 13898 of phase 5 not in submission
# user_id 13920 of phase 5 not in submission
# user_id 13942 of phase 5 not in submission
# user_id 13953 of phase 5 not in submission
# user_id 13975 of phase 5 not in submission
# user_id 13997 of phase 5 not in submission
# user_id 14019 of phase 5 not in submission
# user_id 14030 of phase 5 not in submission
# user_id 14041 of phase 5 not in submission
# user_id 14085 of phase 5 not in submission
# user_id 14118 of phase 5 not in submission
# user_id 14140 of phase 5 not in submission
# user_id 14151 of phase 5 not in submission
# user_id 14173 of phase 5 not in submission
# user_id 14261 of phase 5 not in submission
# user_id 14272 of phase 5 not in submission
# user_id 14283 of phase 5 not in submission
# user_id 14305 of phase 5 not in submission
# user_id 14316 of phase 5 not in submission
# user_id 14338 of phase 5 not in submission
# user_id 14360 of phase 5 not in submission
# user_id 14393 of phase 5 not in submission
# user_id 14404 of phase 5 not in submission
# user_id 14437 of phase 5 not in submission
# user_id 14547 of phase 5 not in submission
# user_id 14569 of phase 5 not in submission
# user_id 14580 of phase 5 not in submission
# user_id 14591 of phase 5 not in submission
# user_id 14602 of phase 5 not in submission
# user_id 14624 of phase 5 not in submission
# user_id 14635 of phase 5 not in submission
# user_id 14646 of phase 5 not in submission
# user_id 14657 of phase 5 not in submission
# user_id 14668 of phase 5 not in submission
# user_id 14690 of phase 5 not in submission
# user_id 14701 of phase 5 not in submission
# user_id 14723 of phase 5 not in submission
# user_id 14745 of phase 5 not in submission
# user_id 14778 of phase 5 not in submission
# user_id 14800 of phase 5 not in submission
# user_id 14899 of phase 5 not in submission
# user_id 14910 of phase 5 not in submission
# user_id 14921 of phase 5 not in submission
# user_id 14954 of phase 5 not in submission
# user_id 14976 of phase 5 not in submission
# user_id 14987 of phase 5 not in submission
# user_id 15020 of phase 5 not in submission
# user_id 15042 of phase 5 not in submission
# user_id 15075 of phase 5 not in submission
# user_id 15086 of phase 5 not in submission
# user_id 15141 of phase 5 not in submission
# user_id 15163 of phase 5 not in submission
# user_id 15174 of phase 5 not in submission
# user_id 15185 of phase 5 not in submission
# user_id 15218 of phase 5 not in submission
# user_id 15262 of phase 5 not in submission
# user_id 15284 of phase 5 not in submission
# user_id 15317 of phase 5 not in submission
# user_id 15328 of phase 5 not in submission
# user_id 15350 of phase 5 not in submission
# user_id 15372 of phase 5 not in submission
# user_id 15383 of phase 5 not in submission
# user_id 15394 of phase 5 not in submission
# user_id 15405 of phase 5 not in submission
# user_id 15416 of phase 5 not in submission
# user_id 15427 of phase 5 not in submission
# user_id 15438 of phase 5 not in submission
# user_id 15449 of phase 5 not in submission
# user_id 15460 of phase 5 not in submission
# user_id 15471 of phase 5 not in submission
# user_id 15482 of phase 5 not in submission
# user_id 15493 of phase 5 not in submission
# user_id 15504 of phase 5 not in submission
# user_id 15526 of phase 5 not in submission
# user_id 15537 of phase 5 not in submission
# user_id 15548 of phase 5 not in submission
# user_id 15559 of phase 5 not in submission
# user_id 15581 of phase 5 not in submission
# user_id 15636 of phase 5 not in submission
# user_id 15647 of phase 5 not in submission
# user_id 15680 of phase 5 not in submission
# user_id 15691 of phase 5 not in submission
# user_id 15702 of phase 5 not in submission
# user_id 15724 of phase 5 not in submission
# user_id 15735 of phase 5 not in submission
# user_id 15746 of phase 5 not in submission
# user_id 15757 of phase 5 not in submission
# user_id 15779 of phase 5 not in submission
# user_id 15790 of phase 5 not in submission
# user_id 15801 of phase 5 not in submission
# user_id 15812 of phase 5 not in submission
# user_id 15845 of phase 5 not in submission
# user_id 15867 of phase 5 not in submission
# user_id 15911 of phase 5 not in submission
# user_id 15933 of phase 5 not in submission
# user_id 15977 of phase 5 not in submission
# user_id 15988 of phase 5 not in submission
# user_id 15999 of phase 5 not in submission
# user_id 16109 of phase 5 not in submission
# user_id 16120 of phase 5 not in submission
# user_id 16131 of phase 5 not in submission
# user_id 16142 of phase 5 not in submission
# user_id 16153 of phase 5 not in submission
# user_id 16164 of phase 5 not in submission
# user_id 16175 of phase 5 not in submission
# user_id 16186 of phase 5 not in submission
# user_id 16197 of phase 5 not in submission
# user_id 16208 of phase 5 not in submission
# user_id 16219 of phase 5 not in submission
# user_id 16230 of phase 5 not in submission
# user_id 16241 of phase 5 not in submission
# user_id 16252 of phase 5 not in submission
# user_id 16296 of phase 5 not in submission
# user_id 16340 of phase 5 not in submission
# user_id 16384 of phase 5 not in submission
# user_id 16439 of phase 5 not in submission
# user_id 16461 of phase 5 not in submission
# user_id 16472 of phase 5 not in submission
# user_id 16494 of phase 5 not in submission
# user_id 16505 of phase 5 not in submission
# user_id 16538 of phase 5 not in submission
# user_id 16549 of phase 5 not in submission
# user_id 16560 of phase 5 not in submission
# user_id 16593 of phase 5 not in submission
# user_id 16604 of phase 5 not in submission
# user_id 16615 of phase 5 not in submission
# user_id 16659 of phase 5 not in submission
# user_id 16670 of phase 5 not in submission
# user_id 16692 of phase 5 not in submission
# user_id 16703 of phase 5 not in submission
# user_id 16725 of phase 5 not in submission
# user_id 16736 of phase 5 not in submission
# user_id 16747 of phase 5 not in submission
# user_id 16758 of phase 5 not in submission
# user_id 16780 of phase 5 not in submission
# user_id 16791 of phase 5 not in submission
# user_id 16802 of phase 5 not in submission
# user_id 16813 of phase 5 not in submission
# user_id 16824 of phase 5 not in submission
# user_id 16835 of phase 5 not in submission
# user_id 16846 of phase 5 not in submission
# user_id 16857 of phase 5 not in submission
# user_id 16868 of phase 5 not in submission
# user_id 16890 of phase 5 not in submission
# user_id 16901 of phase 5 not in submission
# user_id 16912 of phase 5 not in submission
# user_id 16923 of phase 5 not in submission
# user_id 16978 of phase 5 not in submission
# user_id 16989 of phase 5 not in submission
# user_id 17000 of phase 5 not in submission
# user_id 17011 of phase 5 not in submission
# user_id 17033 of phase 5 not in submission
# user_id 17044 of phase 5 not in submission
# user_id 17055 of phase 5 not in submission
# user_id 17066 of phase 5 not in submission
# user_id 17077 of phase 5 not in submission
# user_id 17099 of phase 5 not in submission
# user_id 17132 of phase 5 not in submission
# user_id 17154 of phase 5 not in submission
# user_id 17165 of phase 5 not in submission
# user_id 17176 of phase 5 not in submission
# user_id 17198 of phase 5 not in submission
# user_id 17209 of phase 5 not in submission
# user_id 17220 of phase 5 not in submission
# user_id 17242 of phase 5 not in submission
# user_id 17253 of phase 5 not in submission
# user_id 17264 of phase 5 not in submission
# user_id 17286 of phase 5 not in submission
# user_id 17297 of phase 5 not in submission
# user_id 17308 of phase 5 not in submission
# user_id 17319 of phase 5 not in submission
# user_id 17330 of phase 5 not in submission
# user_id 17352 of phase 5 not in submission
# user_id 17407 of phase 5 not in submission
# user_id 17429 of phase 5 not in submission
# user_id 17440 of phase 5 not in submission
# user_id 17484 of phase 5 not in submission
# user_id 17495 of phase 5 not in submission
# user_id 17517 of phase 5 not in submission
# user_id 17528 of phase 5 not in submission
# user_id 17539 of phase 5 not in submission
# user_id 17550 of phase 5 not in submission
# user_id 17561 of phase 5 not in submission
# user_id 17594 of phase 5 not in submission
# user_id 17605 of phase 5 not in submission
# user_id 17627 of phase 5 not in submission
# user_id 17638 of phase 5 not in submission
# user_id 17660 of phase 5 not in submission
# user_id 17682 of phase 5 not in submission
# user_id 17693 of phase 5 not in submission
# user_id 17704 of phase 5 not in submission
# user_id 17737 of phase 5 not in submission
# user_id 17748 of phase 5 not in submission
# user_id 17770 of phase 5 not in submission
# user_id 17781 of phase 5 not in submission
# user_id 17825 of phase 5 not in submission
# user_id 17836 of phase 5 not in submission
# user_id 17858 of phase 5 not in submission
# user_id 17880 of phase 5 not in submission
# user_id 17902 of phase 5 not in submission
# user_id 17913 of phase 5 not in submission
# user_id 17924 of phase 5 not in submission
# user_id 17935 of phase 5 not in submission
# user_id 17957 of phase 5 not in submission
# user_id 17968 of phase 5 not in submission
# user_id 17990 of phase 5 not in submission
# user_id 18001 of phase 5 not in submission
# user_id 18023 of phase 5 not in submission
# user_id 18045 of phase 5 not in submission
# user_id 18067 of phase 5 not in submission
# user_id 18089 of phase 5 not in submission
# user_id 18100 of phase 5 not in submission
# user_id 18177 of phase 5 not in submission
# user_id 18188 of phase 5 not in submission
# user_id 18232 of phase 5 not in submission
# user_id 18265 of phase 5 not in submission
# user_id 18276 of phase 5 not in submission
# user_id 18298 of phase 5 not in submission
# user_id 18309 of phase 5 not in submission
# user_id 18342 of phase 5 not in submission
# user_id 18353 of phase 5 not in submission
# user_id 18375 of phase 5 not in submission
# user_id 18430 of phase 5 not in submission
# user_id 18441 of phase 5 not in submission
# user_id 18474 of phase 5 not in submission
# user_id 18496 of phase 5 not in submission
# user_id 18507 of phase 5 not in submission
# user_id 18518 of phase 5 not in submission
# user_id 18529 of phase 5 not in submission
# user_id 18540 of phase 5 not in submission
# user_id 18551 of phase 5 not in submission
# user_id 18562 of phase 5 not in submission
# user_id 18573 of phase 5 not in submission
# user_id 18617 of phase 5 not in submission
# user_id 18628 of phase 5 not in submission
# user_id 18639 of phase 5 not in submission
# user_id 18650 of phase 5 not in submission
# user_id 18661 of phase 5 not in submission
# user_id 18694 of phase 5 not in submission
# user_id 18705 of phase 5 not in submission
# user_id 18716 of phase 5 not in submission
# user_id 18727 of phase 5 not in submission
# user_id 18738 of phase 5 not in submission
# user_id 18749 of phase 5 not in submission
# user_id 18793 of phase 5 not in submission
# user_id 18815 of phase 5 not in submission
# user_id 18837 of phase 5 not in submission
# user_id 18848 of phase 5 not in submission
# user_id 18870 of phase 5 not in submission
# user_id 18881 of phase 5 not in submission
# user_id 18936 of phase 5 not in submission
# user_id 18958 of phase 5 not in submission
# user_id 18980 of phase 5 not in submission
# user_id 18991 of phase 5 not in submission
# user_id 19013 of phase 5 not in submission
# user_id 19035 of phase 5 not in submission
# user_id 19046 of phase 5 not in submission
# user_id 19068 of phase 5 not in submission
# user_id 19079 of phase 5 not in submission
# user_id 19101 of phase 5 not in submission
# user_id 19112 of phase 5 not in submission
# user_id 19134 of phase 5 not in submission
# user_id 19156 of phase 5 not in submission
# user_id 19178 of phase 5 not in submission
# user_id 19200 of phase 5 not in submission
# user_id 19211 of phase 5 not in submission
# user_id 19222 of phase 5 not in submission
# user_id 19233 of phase 5 not in submission
# user_id 19244 of phase 5 not in submission
# user_id 19266 of phase 5 not in submission
# user_id 19288 of phase 5 not in submission
# user_id 19299 of phase 5 not in submission
# user_id 19321 of phase 5 not in submission
# user_id 19343 of phase 5 not in submission
# user_id 19365 of phase 5 not in submission
# user_id 19398 of phase 5 not in submission
# user_id 19409 of phase 5 not in submission
# user_id 19420 of phase 5 not in submission
# user_id 19442 of phase 5 not in submission
# user_id 19453 of phase 5 not in submission
# user_id 19464 of phase 5 not in submission
# user_id 19475 of phase 5 not in submission
# user_id 19486 of phase 5 not in submission
# user_id 19508 of phase 5 not in submission
# user_id 19519 of phase 5 not in submission
# user_id 19585 of phase 5 not in submission
# user_id 19596 of phase 5 not in submission
# user_id 19607 of phase 5 not in submission
# user_id 19618 of phase 5 not in submission
# user_id 19651 of phase 5 not in submission
# user_id 19684 of phase 5 not in submission
# user_id 19695 of phase 5 not in submission
# user_id 19728 of phase 5 not in submission
# user_id 19739 of phase 5 not in submission
# user_id 19750 of phase 5 not in submission
# user_id 19805 of phase 5 not in submission
# user_id 19816 of phase 5 not in submission
# user_id 19838 of phase 5 not in submission
# user_id 19849 of phase 5 not in submission
# user_id 19860 of phase 5 not in submission
# user_id 19871 of phase 5 not in submission
# user_id 19882 of phase 5 not in submission
# user_id 19893 of phase 5 not in submission
# user_id 19915 of phase 5 not in submission
# user_id 19937 of phase 5 not in submission
# user_id 19948 of phase 5 not in submission
# user_id 19992 of phase 5 not in submission
# user_id 20003 of phase 5 not in submission
# user_id 20014 of phase 5 not in submission
# user_id 20058 of phase 5 not in submission
# user_id 20080 of phase 5 not in submission
# user_id 20113 of phase 5 not in submission
# user_id 20135 of phase 5 not in submission
# user_id 20146 of phase 5 not in submission
# user_id 20157 of phase 5 not in submission
# user_id 20179 of phase 5 not in submission
# user_id 20190 of phase 5 not in submission
# user_id 20201 of phase 5 not in submission
# user_id 20212 of phase 5 not in submission
# user_id 20223 of phase 5 not in submission
# user_id 20234 of phase 5 not in submission
# user_id 20245 of phase 5 not in submission
# user_id 20256 of phase 5 not in submission
# user_id 20267 of phase 5 not in submission
# user_id 20278 of phase 5 not in submission
# user_id 20344 of phase 5 not in submission
# user_id 20355 of phase 5 not in submission
# user_id 20366 of phase 5 not in submission
# user_id 20377 of phase 5 not in submission
# user_id 20388 of phase 5 not in submission
# user_id 20399 of phase 5 not in submission
# user_id 20410 of phase 5 not in submission
# user_id 20421 of phase 5 not in submission
# user_id 20454 of phase 5 not in submission
# user_id 20465 of phase 5 not in submission
# user_id 20487 of phase 5 not in submission
# user_id 20520 of phase 5 not in submission
# user_id 20542 of phase 5 not in submission
# user_id 20564 of phase 5 not in submission
# user_id 20597 of phase 5 not in submission
# user_id 20630 of phase 5 not in submission
# user_id 20652 of phase 5 not in submission
# user_id 20674 of phase 5 not in submission
# user_id 20696 of phase 5 not in submission
# user_id 20718 of phase 5 not in submission
# user_id 20729 of phase 5 not in submission
# ...
# user_id 27593 of phase 5 not in submission
# user_id 27604 of phase 5 not in submission
# user_id 27637 of phase 5 not in submission
# user_id 27648 of phase 5 not in submission
# user_id 27670 of phase 5 not in submission
# user_id 27681 of phase 5 not in submission
# user_id 27692 of phase 5 not in submission
# user_id 27703 of phase 5 not in submission
# user_id 27725 of phase 5 not in submission
# user_id 27736 of phase 5 not in submission
# user_id 27769 of phase 5 not in submission
# user_id 27780 of phase 5 not in submission
# user_id 27791 of phase 5 not in submission
# user_id 27857 of phase 5 not in submission
# user_id 27868 of phase 5 not in submission
# user_id 27879 of phase 5 not in submission
# user_id 27901 of phase 5 not in submission
# user_id 27934 of phase 5 not in submission
# user_id 27956 of phase 5 not in submission
# user_id 28000 of phase 5 not in submission
# user_id 28011 of phase 5 not in submission
# user_id 28033 of phase 5 not in submission
# user_id 28044 of phase 5 not in submission
# user_id 28055 of phase 5 not in submission
# user_id 28066 of phase 5 not in submission
# user_id 28099 of phase 5 not in submission
# user_id 28110 of phase 5 not in submission
# user_id 28121 of phase 5 not in submission
# user_id 28165 of phase 5 not in submission
# user_id 28176 of phase 5 not in submission
# user_id 28209 of phase 5 not in submission
# user_id 28231 of phase 5 not in submission
# user_id 28242 of phase 5 not in submission
# user_id 28253 of phase 5 not in submission
# user_id 28264 of phase 5 not in submission
# user_id 28275 of phase 5 not in submission
# user_id 28286 of phase 5 not in submission
# user_id 28319 of phase 5 not in submission
# user_id 28330 of phase 5 not in submission
# user_id 28341 of phase 5 not in submission
# user_id 28352 of phase 5 not in submission
# user_id 28385 of phase 5 not in submission
# user_id 28396 of phase 5 not in submission
# user_id 28407 of phase 5 not in submission
# user_id 28418 of phase 5 not in submission
# user_id 28451 of phase 5 not in submission
# user_id 28473 of phase 5 not in submission
# user_id 28495 of phase 5 not in submission
# user_id 28506 of phase 5 not in submission
# user_id 28517 of phase 5 not in submission
# user_id 28539 of phase 5 not in submission
# user_id 28561 of phase 5 not in submission
# user_id 28572 of phase 5 not in submission
# user_id 28605 of phase 5 not in submission
# user_id 28627 of phase 5 not in submission
# user_id 28638 of phase 5 not in submission
# user_id 28660 of phase 5 not in submission
# user_id 28726 of phase 5 not in submission
# user_id 28737 of phase 5 not in submission
# user_id 28781 of phase 5 not in submission
# user_id 28792 of phase 5 not in submission
# user_id 28814 of phase 5 not in submission
# user_id 28825 of phase 5 not in submission
# user_id 28858 of phase 5 not in submission
# user_id 28869 of phase 5 not in submission
# user_id 28880 of phase 5 not in submission
# user_id 28902 of phase 5 not in submission
# user_id 28913 of phase 5 not in submission
# user_id 28924 of phase 5 not in submission
# user_id 28946 of phase 5 not in submission
# user_id 28957 of phase 5 not in submission
# user_id 29001 of phase 5 not in submission
# user_id 29012 of phase 5 not in submission
# user_id 29034 of phase 5 not in submission
# user_id 29045 of phase 5 not in submission
# user_id 29056 of phase 5 not in submission
# user_id 29067 of phase 5 not in submission
# user_id 29089 of phase 5 not in submission
# user_id 29111 of phase 5 not in submission
# user_id 29122 of phase 5 not in submission
# user_id 29144 of phase 5 not in submission
# user_id 29155 of phase 5 not in submission
# user_id 29177 of phase 5 not in submission
# user_id 29188 of phase 5 not in submission
# user_id 29199 of phase 5 not in submission
# user_id 29221 of phase 5 not in submission
# user_id 29232 of phase 5 not in submission
# user_id 29265 of phase 5 not in submission
# user_id 29276 of phase 5 not in submission
# user_id 29320 of phase 5 not in submission
# user_id 29342 of phase 5 not in submission
# user_id 29386 of phase 5 not in submission
# user_id 29397 of phase 5 not in submission
# user_id 29430 of phase 5 not in submission
# user_id 29441 of phase 5 not in submission
# user_id 29452 of phase 5 not in submission
# user_id 29463 of phase 5 not in submission
# user_id 29485 of phase 5 not in submission
# user_id 29496 of phase 5 not in submission
# user_id 29507 of phase 5 not in submission
# user_id 29529 of phase 5 not in submission
# user_id 29551 of phase 5 not in submission
# user_id 29562 of phase 5 not in submission
# user_id 29584 of phase 5 not in submission
# user_id 29595 of phase 5 not in submission
# user_id 29650 of phase 5 not in submission
# user_id 29672 of phase 5 not in submission
# user_id 29716 of phase 5 not in submission
# user_id 29738 of phase 5 not in submission
# user_id 29760 of phase 5 not in submission
# user_id 29771 of phase 5 not in submission
# user_id 29782 of phase 5 not in submission
# user_id 29804 of phase 5 not in submission
# user_id 29815 of phase 5 not in submission
# user_id 29870 of phase 5 not in submission
# user_id 29969 of phase 5 not in submission
# user_id 29991 of phase 5 not in submission
# user_id 30002 of phase 5 not in submission
# user_id 30024 of phase 5 not in submission
# user_id 30035 of phase 5 not in submission
# user_id 30057 of phase 5 not in submission
# user_id 30079 of phase 5 not in submission
# user_id 30123 of phase 5 not in submission
# user_id 30134 of phase 5 not in submission
# user_id 30156 of phase 5 not in submission
# user_id 30167 of phase 5 not in submission
# user_id 30200 of phase 5 not in submission
# user_id 30255 of phase 5 not in submission
# user_id 30266 of phase 5 not in submission
# user_id 30277 of phase 5 not in submission
# user_id 30310 of phase 5 not in submission
# user_id 30332 of phase 5 not in submission
# user_id 30354 of phase 5 not in submission
# user_id 30376 of phase 5 not in submission
# user_id 30387 of phase 5 not in submission
# user_id 30398 of phase 5 not in submission
# user_id 30420 of phase 5 not in submission
# user_id 30431 of phase 5 not in submission
# user_id 30453 of phase 5 not in submission
# user_id 30464 of phase 5 not in submission
# user_id 30475 of phase 5 not in submission
# user_id 30486 of phase 5 not in submission
# user_id 30508 of phase 5 not in submission
# user_id 30530 of phase 5 not in submission
# user_id 30541 of phase 5 not in submission
# user_id 30552 of phase 5 not in submission
# user_id 30563 of phase 5 not in submission
# user_id 30574 of phase 5 not in submission
# user_id 30618 of phase 5 not in submission
# user_id 30629 of phase 5 not in submission
# user_id 30673 of phase 5 not in submission
# user_id 30695 of phase 5 not in submission
# user_id 30706 of phase 5 not in submission
# user_id 30739 of phase 5 not in submission
# user_id 30750 of phase 5 not in submission
# user_id 30761 of phase 5 not in submission
# user_id 30772 of phase 5 not in submission
# user_id 30794 of phase 5 not in submission
# user_id 30827 of phase 5 not in submission
# user_id 30838 of phase 5 not in submission
# user_id 30849 of phase 5 not in submission
# user_id 30860 of phase 5 not in submission
# user_id 30871 of phase 5 not in submission
# user_id 30882 of phase 5 not in submission
# user_id 30893 of phase 5 not in submission
# user_id 30904 of phase 5 not in submission
# user_id 30915 of phase 5 not in submission
# user_id 30937 of phase 5 not in submission
# user_id 30970 of phase 5 not in submission
# user_id 31003 of phase 5 not in submission
# user_id 31014 of phase 5 not in submission
# user_id 31047 of phase 5 not in submission
# user_id 31080 of phase 5 not in submission
# user_id 31113 of phase 5 not in submission
# user_id 31124 of phase 5 not in submission
# user_id 31157 of phase 5 not in submission
# user_id 31168 of phase 5 not in submission
# user_id 31190 of phase 5 not in submission
# user_id 31201 of phase 5 not in submission
# user_id 31223 of phase 5 not in submission
# user_id 31278 of phase 5 not in submission
# user_id 31289 of phase 5 not in submission
# user_id 31311 of phase 5 not in submission
# user_id 31322 of phase 5 not in submission
# user_id 31344 of phase 5 not in submission
# user_id 31388 of phase 5 not in submission
# user_id 31421 of phase 5 not in submission
# user_id 31476 of phase 5 not in submission
# user_id 31542 of phase 5 not in submission
# user_id 31553 of phase 5 not in submission
# user_id 31564 of phase 5 not in submission
# user_id 31597 of phase 5 not in submission
# user_id 31608 of phase 5 not in submission
# user_id 31630 of phase 5 not in submission
# user_id 31685 of phase 5 not in submission
# user_id 31707 of phase 5 not in submission
# user_id 31718 of phase 5 not in submission
# user_id 31751 of phase 5 not in submission
# user_id 31784 of phase 5 not in submission
# user_id 31795 of phase 5 not in submission
# user_id 31806 of phase 5 not in submission
# user_id 31817 of phase 5 not in submission
# user_id 31850 of phase 5 not in submission
# user_id 31872 of phase 5 not in submission
# user_id 31894 of phase 5 not in submission
# user_id 31938 of phase 5 not in submission
# user_id 31949 of phase 5 not in submission
# user_id 31982 of phase 5 not in submission
# user_id 32004 of phase 5 not in submission
# user_id 32015 of phase 5 not in submission
# user_id 32026 of phase 5 not in submission
# user_id 32070 of phase 5 not in submission
# user_id 32081 of phase 5 not in submission
# user_id 32103 of phase 5 not in submission
# user_id 32114 of phase 5 not in submission
# user_id 32158 of phase 5 not in submission
# user_id 32169 of phase 5 not in submission
# user_id 32191 of phase 5 not in submission
# user_id 32213 of phase 5 not in submission
# user_id 32246 of phase 5 not in submission
# user_id 32257 of phase 5 not in submission
# user_id 32268 of phase 5 not in submission
# user_id 32290 of phase 5 not in submission
# user_id 32312 of phase 5 not in submission
# user_id 32323 of phase 5 not in submission
# user_id 32367 of phase 5 not in submission
# user_id 32378 of phase 5 not in submission
# user_id 32400 of phase 5 not in submission
# user_id 32411 of phase 5 not in submission
# user_id 32422 of phase 5 not in submission
# user_id 32444 of phase 5 not in submission
# user_id 32466 of phase 5 not in submission
# user_id 32477 of phase 5 not in submission
# user_id 32488 of phase 5 not in submission
# user_id 32510 of phase 5 not in submission
# user_id 32532 of phase 5 not in submission
# user_id 32554 of phase 5 not in submission
# user_id 32631 of phase 5 not in submission
# user_id 32653 of phase 5 not in submission
# user_id 32708 of phase 5 not in submission
# user_id 32719 of phase 5 not in submission
# user_id 32741 of phase 5 not in submission
# user_id 32752 of phase 5 not in submission
# user_id 32763 of phase 5 not in submission
# user_id 32774 of phase 5 not in submission
# user_id 32873 of phase 5 not in submission
# user_id 32884 of phase 5 not in submission
# user_id 32917 of phase 5 not in submission
# user_id 32928 of phase 5 not in submission
# user_id 32961 of phase 5 not in submission
# user_id 32983 of phase 5 not in submission
# user_id 33038 of phase 5 not in submission
# user_id 33071 of phase 5 not in submission
# user_id 33082 of phase 5 not in submission
# user_id 33093 of phase 5 not in submission
# user_id 33115 of phase 5 not in submission
# user_id 33126 of phase 5 not in submission
# user_id 33137 of phase 5 not in submission
# user_id 33170 of phase 5 not in submission
# user_id 33181 of phase 5 not in submission
# user_id 33192 of phase 5 not in submission
# user_id 33203 of phase 5 not in submission
# user_id 33225 of phase 5 not in submission
# user_id 33291 of phase 5 not in submission
# user_id 33346 of phase 5 not in submission
# user_id 33368 of phase 5 not in submission
# user_id 33390 of phase 5 not in submission
# user_id 33401 of phase 5 not in submission
# user_id 33412 of phase 5 not in submission
# user_id 33423 of phase 5 not in submission
# user_id 33445 of phase 5 not in submission
# user_id 33456 of phase 5 not in submission
# user_id 33467 of phase 5 not in submission
# user_id 33478 of phase 5 not in submission
# user_id 33500 of phase 5 not in submission
# user_id 33522 of phase 5 not in submission
# user_id 33544 of phase 5 not in submission
# user_id 33555 of phase 5 not in submission
# user_id 33588 of phase 5 not in submission
# user_id 33632 of phase 5 not in submission
# user_id 33643 of phase 5 not in submission
# user_id 33665 of phase 5 not in submission
# user_id 33676 of phase 5 not in submission
# user_id 33687 of phase 5 not in submission
# user_id 33698 of phase 5 not in submission
# user_id 33731 of phase 5 not in submission
# user_id 33742 of phase 5 not in submission
# user_id 33753 of phase 5 not in submission
# user_id 33808 of phase 5 not in submission
# user_id 33819 of phase 5 not in submission
# user_id 33863 of phase 5 not in submission
# user_id 33929 of phase 5 not in submission
# user_id 33973 of phase 5 not in submission
# user_id 33984 of phase 5 not in submission
# user_id 34006 of phase 5 not in submission
# user_id 34017 of phase 5 not in submission
# user_id 34050 of phase 5 not in submission
# user_id 34083 of phase 5 not in submission
# user_id 34105 of phase 5 not in submission
# user_id 34116 of phase 5 not in submission
# user_id 34160 of phase 5 not in submission
# user_id 34193 of phase 5 not in submission
# user_id 34237 of phase 5 not in submission
# user_id 34259 of phase 5 not in submission
# user_id 34281 of phase 5 not in submission
# user_id 34303 of phase 5 not in submission
# user_id 34314 of phase 5 not in submission
# user_id 34347 of phase 5 not in submission
# user_id 34369 of phase 5 not in submission
# user_id 34391 of phase 5 not in submission
# user_id 34413 of phase 5 not in submission
# user_id 34424 of phase 5 not in submission
# user_id 34435 of phase 5 not in submission
# user_id 34446 of phase 5 not in submission
# user_id 34457 of phase 5 not in submission
# user_id 34479 of phase 5 not in submission
# user_id 34501 of phase 5 not in submission
# user_id 34523 of phase 5 not in submission
# user_id 34545 of phase 5 not in submission
# user_id 34567 of phase 5 not in submission
# user_id 34589 of phase 5 not in submission
# user_id 34611 of phase 5 not in submission
# user_id 34622 of phase 5 not in submission
# user_id 34644 of phase 5 not in submission
# user_id 34655 of phase 5 not in submission
# user_id 34666 of phase 5 not in submission
# user_id 34688 of phase 5 not in submission
# user_id 34721 of phase 5 not in submission
# user_id 34754 of phase 5 not in submission
# user_id 34798 of phase 5 not in submission
# user_id 34820 of phase 5 not in submission
# user_id 34831 of phase 5 not in submission
# user_id 34842 of phase 5 not in submission
# user_id 34853 of phase 5 not in submission
# user_id 34875 of phase 5 not in submission
# user_id 34930 of phase 5 not in submission
# user_id 34941 of phase 5 not in submission
# user_id 34963 of phase 5 not in submission
# user_id 34996 of phase 5 not in submission
# user_id 35040 of phase 5 not in submission
# user_id 35062 of phase 5 not in submission
# user_id 35095 of phase 5 not in submission
# user_id 35106 of phase 5 not in submission
# user_id 35139 of phase 5 not in submission
# user_id 35150 of phase 5 not in submission
# user_id 35183 of phase 5 not in submission
# user_id 35205 of phase 5 not in submission
# user_id 35238 of phase 5 not in submission
# user_id 35249 of phase 5 not in submission
# user_id 35260 of phase 5 not in submission
# user_id 35282 of phase 5 not in submission
# user_id 35304 of phase 5 not in submission
# user_id 35315 of phase 5 not in submission
# user_id 35337 of phase 5 not in submission
# user_id 35370 of phase 5 not in submission
# user_id 35403 of phase 5 not in submission
# user_id 35425 of phase 5 not in submission
# user_id 35436 of phase 5 not in submission
# error occurred during evaluation
# 1.2314879894256592
# 3.7816720008850098 1.2314879894256592 4.137033939361572 1.4744360446929932
# ((3.7816720008850098,
#   1.2314879894256592,
#   4.137033939361572,
#   1.4744360446929932),
#  {0: array([0.7678894 , 0.25456   , 0.82934785, 0.30067682], dtype=float32),
#   1: array([0.77925843, 0.25543353, 0.86615044, 0.31160575], dtype=float32),
#   2: array([0.791716  , 0.25759798, 0.84988177, 0.30619693], dtype=float32),
#   3: array([0.7671642 , 0.24578968, 0.83682984, 0.29307976], dtype=float32),
#   4: array([0.67564404, 0.21810669, 0.75482404, 0.26287678], dtype=float32)})

# %%
now_phase = 5
submit_fname = '/Users/luoyonggui/Downloads/baseline1_itemcf3.csv'
main(now_phase, submit_fname)
# Out:
# 2020-05-11 15:42:41.180 | INFO     | __main__:create_underexpose_test_qtime_with_answer:6 - phase: 0
# 2020-05-11 15:42:41.266 | INFO     | __main__:create_underexpose_test_qtime_with_answer:6 - phase: 1
# 2020-05-11 15:42:41.352 | INFO     | __main__:create_underexpose_test_qtime_with_answer:6 - phase: 2
# 2020-05-11 15:42:41.439 | INFO     | __main__:create_underexpose_test_qtime_with_answer:6 - phase: 3
# 2020-05-11 15:42:41.522 | INFO     | __main__:create_underexpose_test_qtime_with_answer:6 - phase: 4
# 2020-05-11 15:42:41.620 | INFO     | __main__:create_underexpose_test_qtime_with_answer:6 - phase: 5
# 0
# 1
# 2
# 3
# 4
# 5
# current_time: 1589182964
# date_time: 2020-05-11 15:42:44
# current_phase: 5
# phase_id: 0, score: [0.01743837 0.00581016 0.02391304 0.00832858]
# phase_id: 1, score: [0.01274623 0.00464359 0.01991151 0.00624457]
# phase_id: 2, score: [0.00473373 0.00158052 0.00591017 0.00205374]
# phase_id: 3, score: [0.00776119 0.0033281  0.01048951 0.00459934]
# phase_id: 4, score: [0.01053864 0.00325746 0.01475596 0.00511294]
# phase_id: 5, score: [0.02224694 0.00869069 0.03080308 0.01323797]
# 0.027310509234666824
# 0.07546510547399521 0.027310509234666824 0.10578325390815735 0.03957713767886162
# ((0.07546510547399521,
#   0.027310509234666824,
#   0.10578325390815735,
#   0.03957713767886162),
#  {0: array([0.01743837, 0.00581016, 0.02391304, 0.00832858], dtype=float32),
#   1: array([0.01274623, 0.00464359, 0.01991151, 0.00624457], dtype=float32),
#   2: array([0.00473373, 0.00158052, 0.00591017, 0.00205374], dtype=float32),
#   3: array([0.00776119, 0.0033281 , 0.01048951, 0.00459934], dtype=float32),
#   4: array([0.01053864, 0.00325746, 0.01475596, 0.00511294], dtype=float32),
#   5: array([0.02224694, 0.00869069, 0.03080308, 0.01323797], dtype=float32)})

# %% [markdown]
# # nb

# %%
from nbdev.export import *
notebook2script()
notebook2script('Val.ipynb')
notebook2script('0EDA.ipynb')
# Out:
# Converted Val.ipynb.
# Converted 0EDA.ipynb.
